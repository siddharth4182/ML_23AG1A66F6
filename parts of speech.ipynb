# %% [markdown]
# <a href="https://colab.research.google.com/github/siddharth4182/ML_23AG1A66F6/blob/main/parts%20of%20speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

from collections import Counter

from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('punkt_tab')

text='Balayya is not a name it is an emotion. Jai balayya'

words=word_tokenize (text)

words=[word.lower() for word in words if word.isalnum()]

total_words=len(words)

unique_words=set (words)

word_freq=Counter(words)

longest_word=max(words, key=len)

shortest_word=min(words, key=len)

print('TOTAL_WORDS:', total_words)

print('UNIQUE_WORDS:', unique_words)

print('WORD_FREQ:', word_freq)






print('LONGEST_WORD:', longest_word)

print('SHORTEST_WORD:', shortest_word)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# TOTAL_WORDS: 11
# UNIQUE_WORDS: {'it', 'not', 'balayya', 'a', 'name', 'is', 'emotion', 'an', 'jai'}
# WORD_FREQ: Counter({'balayya': 2, 'is': 2, 'not': 1, 'a': 1, 'name': 1, 'it': 1, 'an': 1, 'emotion': 1, 'jai': 1})
# LONGEST_WORD: balayya
# SHORTEST_WORD: a
