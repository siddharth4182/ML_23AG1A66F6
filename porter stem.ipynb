# %% [markdown]
# <a href="https://colab.research.google.com/github/siddharth4182/ML_23AG1A66F6/blob/main/porter%20stem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.stem import PorterStemmer


ps = PorterStemmer()



words = ["program", "programs", "programmer", "programming", "programmed"]

print("converting Word to it's Stem")

print("-" * 20)

for w in words:

    print(f"{w} -> {ps.stem(w)}")



sentence = "The programmers are programming a new program in Python"

tokenized_words = nltk.word_tokenize(sentence)

print("\nSentence Stemming:")

stemmed_sentence = [ps.stem(w) for w in tokenized_words]

print(" ".join(stemmed_sentence))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# converting Word to it's Stem
# --------------------
# program -> program
# programs -> program
# programmer -> programm
# programming -> program
# programmed -> program
#
# Sentence Stemming:
# the programm are program a new program in python
